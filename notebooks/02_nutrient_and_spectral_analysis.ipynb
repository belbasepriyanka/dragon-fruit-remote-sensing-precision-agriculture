# %% [markdown]
# # 02 — Nutrient and spectral analysis
# PCA and nutrient/spectral relationships on synthetic public data.

# %%
from pathlib import Path
import sys
ROOT=Path.cwd().parent if Path.cwd().name=='notebooks' else Path.cwd()
sys.path.insert(0,str(ROOT))
from src.data_generation import generate_demo_data
from src.spectral_analysis import standardize_and_pca
df=generate_demo_data()
spectral=['ndvi','ndre','gndvi','red_edge_slope','nir_mean','swir_mean']
scores,scaler,pca=standardize_and_pca(df,spectral,2)
pca.explained_variance_ratio_
